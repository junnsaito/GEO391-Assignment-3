# %% [markdown]
# # GEO391 Assignment3

# %% [markdown]
# ##  Vector data
# ### Q1. Plot the spatial ditribution of population in each state
# * Change the colorbar, label the state's name on the map.
# (You should put two labels on the map such as maximum and minimum population, repectively)
# * Consider the range of colorbar which should be appropriated for the result you will expect.
# * Well organize the figure such as the labeling (title of the figure, x and y axisi label).
# * Dowlonding the shapefile data (including every state in USA) from the Moodle
#   (Data sorce here, https://hub.arcgis.com/datasets/USDA-APHIS::states/data)
#
# <img src="population_new.png" style="width: 1000px;">

# %% [markdown]
# ### Q2. Calcurate the population density in each state and plot its spatial distribution
# * Change the colorbar, label the state's name on the map.
# (You should put two labels on the map such as maximum and minimum density, repectively)
# <img src="population_density_new.png" style="width: 1000px;">

# %% [markdown]
# You can start your assingnment using the below coding,

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load shapefile

# %%
import geopandas as gpd
gp_counties = gpd.read_file('./USA_1990-2000_Population_Change.shp')

# %% [markdown]
# Check the content of data (shapefile).

# %%
gp_counties # TOTPOP_CY is population & LANDAREA is area
# Out:
#     OBJECTID  ID                  NAME ST_ABBREV  TOTPOP_CY  RATE_POP  \
# 0          1  02                Alaska        AK     695751       1.3
# 1          2  09           Connecticut        CT    3535787       0.4
# 2          3  15                Hawaii        HI    1309580       0.9
# 3          4  23                 Maine        ME    1338645       0.4
# 4          5  25         Massachusetts        MA    6555736       0.5
# 5          6  33         New Hampshire        NH    1329915       1.1
# 6          7  44          Rhode Island        RI    1058412       0.4
# 7          8  50               Vermont        VT     626078       0.8
# 8          9  08              Colorado        CO    5114102       2.7
# 9         10  20                Kansas        KS    2841378       0.8
# 10        11  31              Nebraska        NE    1822473       0.8
# 11        12  35            New Mexico        NM    2080039       1.9
# ...

# %%
gp_counties.describe() # You can see statics information
# Out:
#         OBJECTID     TOTPOP_CY   RATE_POP  POPGRW00CY  POPGRWCYFY  \
# count  51.000000  5.100000e+01  51.000000   51.000000   51.000000
# mean   26.000000  6.102213e+06   1.229412    0.928627    0.742353
# std    14.866069  6.918563e+06   0.947691    0.684243    0.569314
# min     1.000000  5.481540e+05  -0.600000    0.080000   -0.210000
# 25%    13.500000  1.702085e+06   0.750000    0.470000    0.325000
# 50%    26.000000  4.339471e+06   0.900000    0.740000    0.590000
# 75%    38.500000  6.739690e+06   1.600000    1.245000    1.025000
# max    51.000000  3.798395e+07   5.200000    3.160000    2.410000
#
#             LANDAREA  RATE_POP_1  POPGRW00_1  POPGRWCY_1     LANDAREA_1
# count      51.000000   51.000000   51.000000   51.000000      51.000000
# mean    69361.538114    1.229412    0.928627    0.742353   69361.538114
# std     85696.320160    0.947691    0.684243    0.569314   85696.320160
# min        61.403300   -0.600000    0.080000   -0.210000      61.403300
# ...

# %%
gp_counties.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Exclude Alaska, Puerto Rico and Hawaii in order to see the whole area clearly and then plot the map in USA.
# * %matplotlib notebook is useful to make your figure zoom on the spot

# %%
# %matplotlib notebook 
plt.rcParams['figure.figsize'] = (7, 5) # you can chage the figure size easily.
fig = plt.figure()
ax = fig.add_subplot()
idx = gp_counties['NAME'].isin(['Alaska','Puerto Rico','Hawaii'])
gp_counties = gp_counties[~idx]
gp_counties.plot(facecolor='none',ax=ax, edgecolor='0.5', linewidth=0.5);
ax.set_title('The map of USA')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.text(-110, 46.5, 'MT',fontsize=20, color='k') # You can label whatever letters you like using text
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(-110, 46.5, 'MT')

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import cm
plt.rcParams['figure.figsize'] = (10, 7)
fig = plt.figure()
ax = fig.add_subplot()
divider = make_axes_locatable(ax)
palette = cm.get_cmap('jet', 16)
cax = divider.append_axes("right", size="5%", pad=0.1)
gp_counties.plot(column='TOTPOP_CY',ax=ax, edgecolor='0.1',cax=cax,cmap=palette,legend=True,linewidth=0.5,
                legend_kwds={'label':'Population (per Million)','orientation':'vertical'},vmin = 500000,vmax=40000000);

ax.set_title('Population in USA')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.text(-120, 35, 'CA',fontsize=15, color='w')
ax.text(-109, 42, 'WY',fontsize=15, color='w')
fig.tight_layout()
plt.savefig('population.png',format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# You can check the maximum and minimum population

# %%
mini=gp_counties['TOTPOP_CY'].idxmin() #extract the minimum value
print(gp_counties.loc[int(mini)])# extract its index
# Out:
# OBJECTID                                                           17
# ID                                                                 56
# NAME                                                          Wyoming
# ST_ABBREV                                                          WY
# TOTPOP_CY                                                      548154
# RATE_POP                                                          0.9
# POPGRW00CY                                                       1.02
# POPGRWCYFY                                                       1.22
# LANDAREA                                                   97100.4005
# NAME_12                                                       Wyoming
# ST_ABBREV_                                                         WY
# RATE_POP_1                                                        0.9
# POPGRW00_1                                                       1.02
# ...

# %%
maxi=gp_counties['TOTPOP_CY'].idxmax()
print(gp_counties.loc[int(maxi)])
# Out:
# OBJECTID                                                           19
# ID                                                                 06
# NAME                                                       California
# ST_ABBREV                                                          CA
# TOTPOP_CY                                                    37983948
# RATE_POP                                                          1.3
# POPGRW00CY                                                       1.12
# POPGRWCYFY                                                        0.7
# LANDAREA                                                  155959.3385
# NAME_12                                                    California
# ST_ABBREV_                                                         CA
# RATE_POP_1                                                        1.3
# POPGRW00_1                                                       1.12
# ...

# %%
#plt.rcParams['figure.figsize'] = (12, 12)
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot()
palette = cm.get_cmap('jet', 20)

gp_counties['populate_density'] = gp_counties['TOTPOP_CY'] /gp_counties['LANDAREA'] 
gp_counties.plot(column='populate_density', ax=ax,cmap=palette, legend=True, edgecolor='0.1',linewidth=0.5,
                 legend_kwds={'label':'Population density (/sq mile)','orientation':'horizontal'},vmax=1000,vmin=0)

ax.set_title('Population density')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

min_density=gp_counties['populate_density'].idxmin()
print(gp_counties.loc[int(min_density)])
max_density=gp_counties['populate_density'].idxmax()
print(gp_counties.loc[int(max_density)])

ax.text(-109, 42, 'WY',fontsize=20, color='w')
ax.text(-75, 37.5, 'DC',fontsize=20, color='k')
plt.savefig('population_density_new.png',format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# C:\Users\jsait\anaconda3\envs\stan\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# OBJECTID                                                           17
# ID                                                                 56
# NAME                                                          Wyoming
# ST_ABBREV                                                          WY
# TOTPOP_CY                                                      548154
# RATE_POP                                                          0.9
# POPGRW00CY                                                       1.02
# ...

# %% [markdown]
# ## 2. Raster data (You have to chose a state except for Montana)
# ### Q3 Clip the mean precipitation and temperature data by using shapefile after you calculate them and plot them              as the spatial distribution of mean precipitation and temperture.
# * Downloading the precipitation and temperature (Maximum or Minimum) data during the peropod ST:2019-09-01 ET:2020-08-31 (http://thredds.northwestknowledge.net:8080/thredds/reacch_climate_MET_aggregated_catalog.html) .
# * Select the METDATA (GRIDMET) Precipitation - Daily and METDATA (GRIDMET) Minimum Air Temperature - Daily or  METDATA (GRIDMET)   Maximum Air Temperature - Daily.
# * Select the state you like from the shapefile and clip the raster data using the shapefile.
# * Using the diffrent colorbar except for the below example
#
# <img src="dis_pre_temp.png" style="width: 900px;">
#
# ### Q4 Make a figure on time sieris of changes in temperature and precipitation from Q3 data
# <img src="fig_pre_temp.png" style="width: 800px;">

# %%
gp_counties=gpd.read_file('./USA_1990-2000_Population_Change.shp')

# %% [markdown]
# Take a look at the table carefully and chose a state

# %%
gp_counties

# %% [markdown]
# You can chose a state using the below coding. For instance, if you want to pick up MT, you should select the 20-21 row

# %%
montana=gp_counties[20:21]

# %%
montana
# Out:
#     OBJECTID  ID     NAME ST_ABBREV  TOTPOP_CY  RATE_POP  POPGRW00CY  \
# 20        21  30  Montana        MT     983932       1.2        0.85
#
#     POPGRWCYFY    LANDAREA  NAME_12 ST_ABBREV_  RATE_POP_1  POPGRW00_1  \
# 20        0.92  145552.434  Montana         MT         1.2        0.85
#
#     POPGRWCY_1  LANDAREA_1                                           geometry
# 20        0.92  145552.434  POLYGON ((-111.04898 44.47407, -111.12265 44.4...

# %% [markdown]
# You can save gp_counties (include whole state) as montana (only Montana state) which is save as Counties_MT.shp

# %%
file_shp ='./State_MT.shp'
montana.to_file(file_shp)

# %% [markdown]
# Clip precipitation and temperature data in a state you chose using shapefile.
# And then, you save raster data as tif file from nc file. Tiff and nc file are a kind of raster data.

# %%
import fiona
import rasterio as rio
import rasterio.mask
from rasterio.plot import show
from rasterio.warp import calculate_default_transform, reproject, Resampling

# read shape file
with fiona.open("./State_MT.shp", "r") as shapefile:
    shape = [feature["geometry"] for feature in shapefile]

# read imagery file and clip it with shape file
with rasterio.open('./precip_F2015-09-01_T2016-08-31.nc') as src:
    out_image, out_transform = rasterio.mask.mask(src, shape, crop=True)
    out_meta = src.meta

with rasterio.open('./temp_F2015-09-01_T2016-08-31.nc') as src2:
    out_image2, out_transform2 = rasterio.mask.mask(src2, shape, crop=True)
    out_meta2 = src2.meta

#Save clipped imagery
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

#Change the file name every time you save it using the below code if you want to run the code.  
with rasterio.open("./montana_pre.tif", "w", **out_meta) as dest1:
    dest1.write(out_image)  

out_meta2.update({"driver": "GTiff",
                 "height": out_image2.shape[1],
                 "width": out_image2.shape[2],
                 "transform": out_transform2})

with rasterio.open("./montana_temp.tif", "w", **out_meta2) as dest2:
    dest2.write(out_image2)

# %% [markdown]
# Calculate mean precipitation and temperature (See the material you have)

# %%
#To calculate mean precipitation 
rPrecip=rio.open('./montana_pre.tif')
npPrecip=rPrecip.read(masked=True)
npPrecip=(npPrecip.T*rPrecip.scales).T
npmeanPrecip=np.mean(npPrecip, axis=0)

#To calculate mean temperature
rtemp=rio.open('./montana_temp.tif')
nptemp=rtemp.read(masked=True)
nptemp=(nptemp.T*rtemp.scales).T
meantemp=np.mean(nptemp, axis=0)
meantemp=(meantemp/10 - 32)*5/9  # To convert F to C degree

# %% [markdown]
# The datetime module supplies classes for manipulating dates and times. You should make a datetime during 2019-09-01 - 2020-08-31 referencing the below coding.

# %%
from datetime import datetime as dt
from datetime import timedelta

#Setting the start and end date
strdt = dt.strptime("2015-09-01", '%Y-%m-%d')  # Start
enddt = dt.strptime("2016-08-31", '%Y-%m-%d')  # End

# Calculate the range of date you focus on
days_num = (enddt - strdt).days +1 
datelist = []
for i in range(days_num):
    datelist.append(strdt + timedelta(days=i))


# Check the datelist you made
for d in datelist:
    print(d.strftime("%Y-%m-%d"))
# Out:
# 2015-09-01
# 2015-09-02
# 2015-09-03
# 2015-09-04
# 2015-09-05
# 2015-09-06
# 2015-09-07
# 2015-09-08
# 2015-09-09
# 2015-09-10
# 2015-09-11
# 2015-09-12
# 2015-09-13
# 2015-09-14
# 2015-09-15
# 2015-09-16
# 2015-09-17
# 2015-09-18
# 2015-09-19
# 2015-09-20
# 2015-09-21
# 2015-09-22
# 2015-09-23
# 2015-09-24
# 2015-09-25
# 2015-09-26
# 2015-09-27
# 2015-09-28
# 2015-09-29
# 2015-09-30
# 2015-10-01
# 2015-10-02
# 2015-10-03
# 2015-10-04
# 2015-10-05
# 2015-10-06
# 2015-10-07
# 2015-10-08
# 2015-10-09
# 2015-10-10
# 2015-10-11
# 2015-10-12
# 2015-10-13
# 2015-10-14
# 2015-10-15
# 2015-10-16
# 2015-10-17
# 2015-10-18
# 2015-10-19
# 2015-10-20
# 2015-10-21
# 2015-10-22
# 2015-10-23
# 2015-10-24
# 2015-10-25
# 2015-10-26
# 2015-10-27
# 2015-10-28
# 2015-10-29
# 2015-10-30
# 2015-10-31
# 2015-11-01
# 2015-11-02
# 2015-11-03
# 2015-11-04
# 2015-11-05
# 2015-11-06
# 2015-11-07
# 2015-11-08
# 2015-11-09
# 2015-11-10
# 2015-11-11
# 2015-11-12
# 2015-11-13
# 2015-11-14
# 2015-11-15
# ...

# %% [markdown]
# Extract mean value on each date using for loop

# %%
pre=[]
for i in range(366):
    data=np.mean(npPrecip[i,:,:])
    pre.append(data)

temp=[]
for i in range(366):
    data1=np.mean(nptemp[i,:,:])
    temp.append(data1)

# %% [markdown]
# Make the array of precipitation and temperature using np.array. After that, temperature should be converted from F to C defree

# %%
pre=np.array(pre)
temp=np.array(temp)
temp=(temp/10 - 32)*5/9

# %% [markdown]
# Make the precipitaton and temperature plot in a figure.
# You should make double y axis like this,
# * fig = plt.figure()
# * ax1 = fig.add_subplot()
# * ax1.bar() # to plot precipitation
# * ax2 = ax1.twinx() # to add double y axis
# * ax2.plot()# to plot temperature
#
# if you want to make x-and y-tick label bigger, use this,
# * ax1.tick_params('y', colors='b',labelsize='15')
# * ax2.tick_params('y', colors='r',labelsize='15')

# %%
#fig, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (10, 7)
fig = plt.figure()
ax1 = fig.add_subplot()
ax1.bar(datelist,pre)
ax1.set_ylabel('Precipitation (mm)', color='b',fontsize=15)
ax1.set_xlabel('Time', color='k',fontsize=15)
ax1.tick_params('y', colors='b',labelsize='15')
#ax1.set_ylim(top=200)


ax2 = ax1.twinx()
ax2.plot(datelist,temp,color='r')
ax2.set_ylabel('Temperature degree C', color='r',fontsize=15)


ax2.tick_params('y', colors='r',labelsize='15')

fig.tight_layout()
plt.show()
fig.savefig('fig_pre_temp.png',format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Make a figure on the clipped data
# * rasterio.plot.plotting_extent() is used to get the boudary information on the data.
# * plt.imshow() is often used when loading TIF file.

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import cm
plt.rcParams['figure.figsize'] = (10, 5)
fig=plt.figure()
ax=fig.add_subplot(121)
spatial_extent_a = rasterio.plot.plotting_extent(rPrecip)
spatial_extent = rasterio.plot.plotting_extent(rtemp) 
palette=cm.get_cmap('viridis',256)


raster_image=plt.imshow(npmeanPrecip,extent=spatial_extent_a)
idx = gp_counties['NAME'].isin(['Alaska','Puerto Rico','Hawaii'])
gp_counties = gp_counties[~idx]
vector_image=gp_counties.plot(ax=ax, facecolor="none",edgecolor='black', lw=1)
ax.set_title('USA')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
cb = fig.colorbar(raster_image, orientation='horizontal',pad=0.1)
cb.set_label('Precipitation (mm)', fontsize= 14)


ax2=fig.add_subplot(122)
raster_image2=plt.imshow(meantemp,extent=spatial_extent)
idx = gp_counties['NAME'].isin(['Alaska','Puerto Rico','Hawaii'])
gp_counties = gp_counties[~idx]
vector_image=gp_counties.plot(ax=ax2, facecolor="none",edgecolor='black', lw=1)
ax2.set_title('USA')

ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')

cb2 = fig.colorbar(raster_image2, orientation='horizontal',pad=0.1)
cb2.set_label('Temperature (Degree C)', fontsize= 14)
fig.tight_layout()
#fig.savefig('dis_pre_temp.png',format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1000">
